# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam

import collections
import os
import numpy as np
import pandas as pd
import pretty_midi
from matplotlib import pyplot as plt

from typing import Dict, List, Optional, Sequence, Tuple
import seaborn as sns

# %%
# Creating the required variables
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# Sampling rate for audio playback
_SAMPLING_RATE = 16000

# %%
# Setting the path and loading the data
data_dir = "MIDI Files/Extracted Data/"
filenames = next(os.walk(data_dir))[2]

print("Number of files: ", len(filenames))
# Out:
# Number of files:  5

# %%
sample_file = filenames[0]
sample_dir = str(data_dir + sample_file)
print(sample_file)

pm = pretty_midi.PrettyMIDI(sample_dir)

print('Number of instruments:', len(pm.instruments))
instrument = pm.instruments[0]
instrument_name = pretty_midi.program_to_instrument_name(instrument.program)
print('Instrument name:', instrument_name)

# Extracting the notes
for i, note in enumerate(instrument.notes[:10]):
    note_name = pretty_midi.note_number_to_name(note.pitch)
    duration = note.end - note.start
    print(f'{i}: pitch={note.pitch}, note_name={note_name}, duration={duration:.4f}')
# Out:
# Black_Dog.mid
# Number of instruments: 1
# Instrument name: Electric Guitar (clean)
# 0: pitch=52, note_name=E3, duration=0.1992
# 1: pitch=55, note_name=G3, duration=0.1992
# 2: pitch=56, note_name=G#3, duration=0.1992
# 3: pitch=57, note_name=A3, duration=0.1992
# 4: pitch=52, note_name=E3, duration=0.1992
# 5: pitch=60, note_name=C4, duration=0.3992
# 6: pitch=57, note_name=A3, duration=0.3992
# 7: pitch=62, note_name=D4, duration=0.1992
# 8: pitch=64, note_name=E4, duration=0.1992
# 9: pitch=60, note_name=C4, duration=0.1325

# %%
# Extracting the notes from the sample MIDI file

def midi_to_notes(midi_file: str) -> pd.DataFrame:
    pm = pretty_midi.PrettyMIDI(midi_file)
    instrument = pm.instruments[0]
    notes = collections.defaultdict(list)

    # Sort the notes by start time
    sorted_notes = sorted(instrument.notes, key=lambda note: note.start)
    prev_start = sorted_notes[0].start

    for note in sorted_notes:
        start = note.start
        end = note.end
        notes['pitch'].append(note.pitch)
        notes['start'].append(start)
        notes['end'].append(end)
        notes['step'].append(start - prev_start)
        notes['duration'].append(end - start)
        prev_start = start

    return pd.DataFrame({name: np.array(value) for name, value in notes.items()})

raw_notes = midi_to_notes(sample_dir)
raw_notes.head()
# Out:
#    pitch  start       end  step  duration
# 0     52    8.2  8.399167   0.0  0.199167
# 1     55    8.4  8.599167   0.2  0.199167
# 2     56    8.6  8.799167   0.2  0.199167
# 3     57    8.8  8.999167   0.2  0.199167
# 4     52    9.0  9.199167   0.2  0.199167

# %%
# Converting to note names by considering the respective pitch values

get_note_names = np.vectorize(pretty_midi.note_number_to_name)
sample_note_names = get_note_names(raw_notes['pitch'])
print(sample_note_names[:10])

# Visualizing the paramaters of the muscial notes of the piano

def plot_piano_roll(notes: pd.DataFrame, count: Optional[int] = None):
    if count:
        title = f'First {count} notes'
    else:
        title = f'Whole track'
        count = len(notes['pitch'])
        
        plt.figure(figsize=(20, 4))
        plot_pitch = np.stack([notes['pitch'], notes['pitch']], axis=0)
        plot_start_stop = np.stack([notes['start'], notes['end']], axis=0)
        
        plt.plot(plot_start_stop[:, :count], plot_pitch[:, :count], color="b", marker=".")
        plt.xlabel('Time [s]')
        plt.ylabel('Pitch')
        _ = plt.title(title)
# Out:
# ['E3' 'G3' 'G#3' 'A3' 'E3' 'C4' 'A3' 'D4' 'E4' 'C4']

# %%
def notes_to_midi(notes: pd.DataFrame, out_file: str, instrument_name: str,
                  velocity: int = 100) -> pretty_midi.PrettyMIDI:

    pm = pretty_midi.PrettyMIDI()
    instrument = pretty_midi.Instrument(
      program=pretty_midi.instrument_name_to_program(
          instrument_name))

    prev_start = 0
    for i, note in notes.iterrows():
        start = float(prev_start + note['step'])
        end = float(start + note['duration'])
        
        note = pretty_midi.Note(velocity=velocity, pitch=int(note['pitch']),
                                start=start, end=end)
        instrument.notes.append(note)
        prev_start = start

    pm.instruments.append(instrument)
    pm.write(out_file)
    return pm

example_file = 'example.midi'
example_pm = notes_to_midi(
    raw_notes, out_file=example_file, instrument_name=instrument_name)

# %%
num_files = 5
all_notes = []
for f in filenames[:num_files]:
    notes = midi_to_notes(str(data_dir+f))
    all_notes.append(notes)

all_notes = pd.concat(all_notes)

n_notes = len(all_notes)
print('Number of notes parsed:', n_notes)

key_order = ['pitch', 'step', 'duration']
train_notes = np.stack([all_notes[key] for key in key_order], axis=1)

notes_ds = tf.data.Dataset.from_tensor_slices(train_notes)
notes_ds.element_spec
# Out:
# Number of notes parsed: 5836
# TensorSpec(shape=(3,), dtype=tf.float64, name=None)

# %%
def create_sequences(dataset: tf.data.Dataset, seq_length: int,
                     vocab_size = 128) -> tf.data.Dataset:
    """Returns TF Dataset of sequence and label examples."""
    seq_length = seq_length+1

    # Take 1 extra for the labels
    windows = dataset.window(seq_length, shift=1, stride=1,
                              drop_remainder=True)

    # `flat_map` flattens the" dataset of datasets" into a dataset of tensors
    flatten = lambda x: x.batch(seq_length, drop_remainder=True)
    sequences = windows.flat_map(flatten)

    # Normalize note pitch
    def scale_pitch(x):
        x = x/[vocab_size,1.0,1.0]
        return x

    # Split the labels
    def split_labels(sequences):
        inputs = sequences[:-1]
        labels_dense = sequences[-1]
        labels = {key:labels_dense[i] for i,key in enumerate(key_order)}

        return scale_pitch(inputs), labels

    return sequences.map(split_labels, num_parallel_calls=tf.data.AUTOTUNE)
    
seq_length = 25
vocab_size = 128
seq_ds = create_sequences(notes_ds, seq_length, vocab_size)

# %%
batch_size = 128
buffer_size = n_notes - seq_length  # the number of items in the dataset
train_ds = (seq_ds
            .shuffle(buffer_size)
            .batch(batch_size, drop_remainder=True)
            .cache()
            .prefetch(tf.data.experimental.AUTOTUNE))

# %%
def mse_with_positive_pressure(y_true: tf.Tensor, y_pred: tf.Tensor):
    mse = (y_true - y_pred) ** 2
    positive_pressure = 10 * tf.maximum(-y_pred, 0.0)
    return tf.reduce_mean(mse + positive_pressure)

# %%
# Developing the model

input_shape = (seq_length, 3)
learning_rate = 0.005

inputs = Input(input_shape)
x = LSTM(128)(inputs)

outputs = {'pitch': Dense(128, name='pitch')(x),
           'step': Dense(1, name='step')(x),
           'duration': Dense(1, name='duration')(x),
          }

model = Model(inputs, outputs)

loss = {'pitch': SparseCategoricalCrossentropy(from_logits=True),
        'step': mse_with_positive_pressure,
        'duration': mse_with_positive_pressure,
       }

optimizer = Adam(learning_rate=learning_rate)

model.compile(loss=loss, optimizer=optimizer)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 25, 3)]      0           []
#
#  lstm (LSTM)                    (None, 128)          67584       ['input_1[0][0]']
#
#  duration (Dense)               (None, 1)            129         ['lstm[0][0]']
#
#  pitch (Dense)                  (None, 128)          16512       ['lstm[0][0]']
#
#  step (Dense)                   (None, 1)            129         ['lstm[0][0]']
#
# ==================================================================================================
# Total params: 84,354
# Trainable params: 84,354
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Creating the necessary callbacks

callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath='./training_checkpoints/ckpt_{epoch}', save_weights_only=True),]

#callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath='./training_checkpoints/ckpt_{epoch}', save_weights_only=True),
#             tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, 
#                                              verbose=1, restore_best_weights=True),]

# %%
# Compiling and fitting the model

model.compile(loss = loss, 
              loss_weights = {'pitch': 0.05, 'step': 1.0, 'duration':1.0,},
              optimizer = optimizer)

epochs = 200

history = model.fit(train_ds, 
                    epochs=epochs, 
                    callbacks=callbacks,)
# Out:
# Epoch 1/200
# 45/45 [==============================] - 6s 67ms/step - loss: 1.0270 - duration_loss: 0.3845 - pitch_loss: 3.9023 - step_loss: 0.4474
# Epoch 2/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.8446 - duration_loss: 0.3055 - pitch_loss: 3.0334 - step_loss: 0.3875
# Epoch 3/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.7844 - duration_loss: 0.2799 - pitch_loss: 2.8575 - step_loss: 0.3616
# Epoch 4/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.7426 - duration_loss: 0.2629 - pitch_loss: 2.8312 - step_loss: 0.3382
# Epoch 5/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.7122 - duration_loss: 0.2521 - pitch_loss: 2.8135 - step_loss: 0.3194
# Epoch 6/200
# 45/45 [==============================] - 1s 31ms/step - loss: 0.6764 - duration_loss: 0.2440 - pitch_loss: 2.7856 - step_loss: 0.2931
# Epoch 7/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.6413 - duration_loss: 0.2434 - pitch_loss: 2.7895 - step_loss: 0.2584
# Epoch 8/200
# 45/45 [==============================] - 1s 29ms/step - loss: 0.6178 - duration_loss: 0.2363 - pitch_loss: 2.7595 - step_loss: 0.2435
# Epoch 9/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.5833 - duration_loss: 0.2381 - pitch_loss: 2.7506 - step_loss: 0.2077
# Epoch 10/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.6022 - duration_loss: 0.2377 - pitch_loss: 2.8004 - step_loss: 0.2244
# Epoch 11/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.5582 - duration_loss: 0.2280 - pitch_loss: 2.7758 - step_loss: 0.1914
# Epoch 12/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.5411 - duration_loss: 0.2268 - pitch_loss: 2.7308 - step_loss: 0.1777
# Epoch 13/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.5208 - duration_loss: 0.2229 - pitch_loss: 2.6719 - step_loss: 0.1643
# Epoch 14/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.5047 - duration_loss: 0.2182 - pitch_loss: 2.6537 - step_loss: 0.1538
# Epoch 15/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.5206 - duration_loss: 0.2239 - pitch_loss: 2.7041 - step_loss: 0.1615
# Epoch 16/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.4912 - duration_loss: 0.2217 - pitch_loss: 2.6606 - step_loss: 0.1364
# Epoch 17/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.4661 - duration_loss: 0.2114 - pitch_loss: 2.6114 - step_loss: 0.1241
# Epoch 18/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.4589 - duration_loss: 0.2079 - pitch_loss: 2.5841 - step_loss: 0.1219
# Epoch 19/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.4378 - duration_loss: 0.1964 - pitch_loss: 2.5534 - step_loss: 0.1137
# Epoch 20/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.4471 - duration_loss: 0.1992 - pitch_loss: 2.5619 - step_loss: 0.1198
# Epoch 21/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.4437 - duration_loss: 0.1974 - pitch_loss: 2.5527 - step_loss: 0.1187
# Epoch 22/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.4133 - duration_loss: 0.1846 - pitch_loss: 2.4959 - step_loss: 0.1039
# Epoch 23/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.4143 - duration_loss: 0.1820 - pitch_loss: 2.5623 - step_loss: 0.1042
# Epoch 24/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.4325 - duration_loss: 0.1933 - pitch_loss: 2.5742 - step_loss: 0.1104
# Epoch 25/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.7525 - duration_loss: 0.2613 - pitch_loss: 2.6486 - step_loss: 0.3587
# Epoch 26/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.5954 - duration_loss: 0.2360 - pitch_loss: 2.6565 - step_loss: 0.2266
# Epoch 27/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.4908 - duration_loss: 0.2175 - pitch_loss: 2.5937 - step_loss: 0.1436
# Epoch 28/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.4324 - duration_loss: 0.2018 - pitch_loss: 2.5379 - step_loss: 0.1037
# Epoch 29/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.4185 - duration_loss: 0.1916 - pitch_loss: 2.5066 - step_loss: 0.1016
# Epoch 30/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.4169 - duration_loss: 0.1918 - pitch_loss: 2.4958 - step_loss: 0.1003
# Epoch 31/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3977 - duration_loss: 0.1764 - pitch_loss: 2.4731 - step_loss: 0.0976
# Epoch 32/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3993 - duration_loss: 0.1755 - pitch_loss: 2.5282 - step_loss: 0.0974
# Epoch 33/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.4009 - duration_loss: 0.1760 - pitch_loss: 2.5697 - step_loss: 0.0964
# Epoch 34/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3814 - duration_loss: 0.1612 - pitch_loss: 2.4850 - step_loss: 0.0959
# Epoch 35/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3874 - duration_loss: 0.1683 - pitch_loss: 2.5176 - step_loss: 0.0932
# Epoch 36/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.4189 - duration_loss: 0.1959 - pitch_loss: 2.5246 - step_loss: 0.0967
# Epoch 37/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3963 - duration_loss: 0.1796 - pitch_loss: 2.4682 - step_loss: 0.0933
# Epoch 38/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3924 - duration_loss: 0.1753 - pitch_loss: 2.4674 - step_loss: 0.0938
# Epoch 39/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.3952 - duration_loss: 0.1752 - pitch_loss: 2.4909 - step_loss: 0.0954
# Epoch 40/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.3584 - duration_loss: 0.1451 - pitch_loss: 2.4336 - step_loss: 0.0916
# Epoch 41/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.4131 - duration_loss: 0.1925 - pitch_loss: 2.4740 - step_loss: 0.0970
# Epoch 42/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3855 - duration_loss: 0.1673 - pitch_loss: 2.4742 - step_loss: 0.0945
# Epoch 43/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.4123 - duration_loss: 0.1933 - pitch_loss: 2.4846 - step_loss: 0.0947
# Epoch 44/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.4191 - duration_loss: 0.1966 - pitch_loss: 2.5147 - step_loss: 0.0968
# Epoch 45/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3960 - duration_loss: 0.1809 - pitch_loss: 2.4367 - step_loss: 0.0932
# Epoch 46/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.3981 - duration_loss: 0.1836 - pitch_loss: 2.4122 - step_loss: 0.0939
# Epoch 47/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3869 - duration_loss: 0.1755 - pitch_loss: 2.3924 - step_loss: 0.0918
# Epoch 48/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.3653 - duration_loss: 0.1561 - pitch_loss: 2.3759 - step_loss: 0.0904
# Epoch 49/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3493 - duration_loss: 0.1432 - pitch_loss: 2.3606 - step_loss: 0.0881
# Epoch 50/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3504 - duration_loss: 0.1448 - pitch_loss: 2.3464 - step_loss: 0.0882
# Epoch 51/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3436 - duration_loss: 0.1406 - pitch_loss: 2.3214 - step_loss: 0.0869
# Epoch 52/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.3388 - duration_loss: 0.1356 - pitch_loss: 2.3108 - step_loss: 0.0876
# Epoch 53/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3332 - duration_loss: 0.1308 - pitch_loss: 2.2975 - step_loss: 0.0875
# Epoch 54/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3317 - duration_loss: 0.1291 - pitch_loss: 2.2826 - step_loss: 0.0885
# Epoch 55/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3284 - duration_loss: 0.1288 - pitch_loss: 2.2668 - step_loss: 0.0863
# Epoch 56/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.3263 - duration_loss: 0.1280 - pitch_loss: 2.2528 - step_loss: 0.0856
# Epoch 57/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.3231 - duration_loss: 0.1265 - pitch_loss: 2.2345 - step_loss: 0.0848
# Epoch 58/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3220 - duration_loss: 0.1258 - pitch_loss: 2.2205 - step_loss: 0.0852
# Epoch 59/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3197 - duration_loss: 0.1247 - pitch_loss: 2.2056 - step_loss: 0.0847
# Epoch 60/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3200 - duration_loss: 0.1243 - pitch_loss: 2.1944 - step_loss: 0.0860
# Epoch 61/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3168 - duration_loss: 0.1230 - pitch_loss: 2.1757 - step_loss: 0.0850
# Epoch 62/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3150 - duration_loss: 0.1223 - pitch_loss: 2.1642 - step_loss: 0.0844
# Epoch 63/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3120 - duration_loss: 0.1208 - pitch_loss: 2.1412 - step_loss: 0.0841
# Epoch 64/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3105 - duration_loss: 0.1208 - pitch_loss: 2.1225 - step_loss: 0.0835
# Epoch 65/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3090 - duration_loss: 0.1197 - pitch_loss: 2.1036 - step_loss: 0.0842
# Epoch 66/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3108 - duration_loss: 0.1203 - pitch_loss: 2.0767 - step_loss: 0.0867
# Epoch 67/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.3058 - duration_loss: 0.1183 - pitch_loss: 2.0645 - step_loss: 0.0843
# Epoch 68/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.3068 - duration_loss: 0.1184 - pitch_loss: 2.0645 - step_loss: 0.0852
# Epoch 69/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3231 - duration_loss: 0.1378 - pitch_loss: 2.0420 - step_loss: 0.0832
# Epoch 70/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.3346 - duration_loss: 0.1356 - pitch_loss: 2.1737 - step_loss: 0.0903
# Epoch 71/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3208 - duration_loss: 0.1260 - pitch_loss: 2.1163 - step_loss: 0.0890
# Epoch 72/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3200 - duration_loss: 0.1327 - pitch_loss: 2.0700 - step_loss: 0.0837
# Epoch 73/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3372 - duration_loss: 0.1500 - pitch_loss: 2.0505 - step_loss: 0.0846
# Epoch 74/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3393 - duration_loss: 0.1505 - pitch_loss: 2.0471 - step_loss: 0.0864
# Epoch 75/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.3132 - duration_loss: 0.1279 - pitch_loss: 2.0123 - step_loss: 0.0847
# Epoch 76/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.3240 - duration_loss: 0.1413 - pitch_loss: 2.0030 - step_loss: 0.0826
# Epoch 77/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3241 - duration_loss: 0.1397 - pitch_loss: 2.0413 - step_loss: 0.0824
# Epoch 78/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3238 - duration_loss: 0.1431 - pitch_loss: 1.9736 - step_loss: 0.0820
# Epoch 79/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.3636 - duration_loss: 0.1697 - pitch_loss: 2.0997 - step_loss: 0.0889
# Epoch 80/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.3326 - duration_loss: 0.1447 - pitch_loss: 2.0467 - step_loss: 0.0856
# Epoch 81/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.3084 - duration_loss: 0.1303 - pitch_loss: 1.9273 - step_loss: 0.0817
# Epoch 82/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2943 - duration_loss: 0.1173 - pitch_loss: 1.9090 - step_loss: 0.0815
# Epoch 83/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2832 - duration_loss: 0.1132 - pitch_loss: 1.8290 - step_loss: 0.0786
# Epoch 84/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2752 - duration_loss: 0.1078 - pitch_loss: 1.7653 - step_loss: 0.0791
# Epoch 85/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2721 - duration_loss: 0.1054 - pitch_loss: 1.7249 - step_loss: 0.0805
# Epoch 86/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2655 - duration_loss: 0.1025 - pitch_loss: 1.6821 - step_loss: 0.0789
# Epoch 87/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2608 - duration_loss: 0.0998 - pitch_loss: 1.6570 - step_loss: 0.0782
# Epoch 88/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2562 - duration_loss: 0.0981 - pitch_loss: 1.6072 - step_loss: 0.0778
# Epoch 89/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2520 - duration_loss: 0.0959 - pitch_loss: 1.5751 - step_loss: 0.0773
# Epoch 90/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2492 - duration_loss: 0.0960 - pitch_loss: 1.5501 - step_loss: 0.0757
# Epoch 91/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.2473 - duration_loss: 0.0942 - pitch_loss: 1.5320 - step_loss: 0.0765
# Epoch 92/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2449 - duration_loss: 0.0932 - pitch_loss: 1.4901 - step_loss: 0.0772
# Epoch 93/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2409 - duration_loss: 0.0916 - pitch_loss: 1.4702 - step_loss: 0.0758
# Epoch 94/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.2373 - duration_loss: 0.0912 - pitch_loss: 1.4385 - step_loss: 0.0741
# Epoch 95/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2346 - duration_loss: 0.0888 - pitch_loss: 1.4282 - step_loss: 0.0744
# Epoch 96/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2319 - duration_loss: 0.0872 - pitch_loss: 1.4037 - step_loss: 0.0745
# Epoch 97/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.2344 - duration_loss: 0.0880 - pitch_loss: 1.4003 - step_loss: 0.0764
# Epoch 98/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2296 - duration_loss: 0.0852 - pitch_loss: 1.3654 - step_loss: 0.0761
# Epoch 99/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2235 - duration_loss: 0.0840 - pitch_loss: 1.3283 - step_loss: 0.0731
# Epoch 100/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2206 - duration_loss: 0.0831 - pitch_loss: 1.2962 - step_loss: 0.0727
# Epoch 101/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.2187 - duration_loss: 0.0812 - pitch_loss: 1.2769 - step_loss: 0.0737
# Epoch 102/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2159 - duration_loss: 0.0807 - pitch_loss: 1.2588 - step_loss: 0.0723
# Epoch 103/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2103 - duration_loss: 0.0784 - pitch_loss: 1.2180 - step_loss: 0.0710
# Epoch 104/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.2119 - duration_loss: 0.0797 - pitch_loss: 1.2090 - step_loss: 0.0718
# Epoch 105/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.2105 - duration_loss: 0.0776 - pitch_loss: 1.2108 - step_loss: 0.0724
# Epoch 106/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.2059 - duration_loss: 0.0759 - pitch_loss: 1.1690 - step_loss: 0.0716
# Epoch 107/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.2014 - duration_loss: 0.0745 - pitch_loss: 1.1346 - step_loss: 0.0702
# Epoch 108/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.2024 - duration_loss: 0.0762 - pitch_loss: 1.1303 - step_loss: 0.0697
# Epoch 109/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.2232 - duration_loss: 0.0916 - pitch_loss: 1.1900 - step_loss: 0.0721
# Epoch 110/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.2203 - duration_loss: 0.0924 - pitch_loss: 1.1652 - step_loss: 0.0697
# Epoch 111/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2124 - duration_loss: 0.0856 - pitch_loss: 1.1289 - step_loss: 0.0703
# Epoch 112/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.2319 - duration_loss: 0.0941 - pitch_loss: 1.3442 - step_loss: 0.0706
# Epoch 113/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2074 - duration_loss: 0.0762 - pitch_loss: 1.1736 - step_loss: 0.0725
# Epoch 114/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1981 - duration_loss: 0.0725 - pitch_loss: 1.0938 - step_loss: 0.0709
# Epoch 115/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1908 - duration_loss: 0.0690 - pitch_loss: 1.0521 - step_loss: 0.0691
# Epoch 116/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.1897 - duration_loss: 0.0672 - pitch_loss: 1.0637 - step_loss: 0.0694
# Epoch 117/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1876 - duration_loss: 0.0666 - pitch_loss: 1.0443 - step_loss: 0.0689
# Epoch 118/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1819 - duration_loss: 0.0632 - pitch_loss: 1.0020 - step_loss: 0.0686
# Epoch 119/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1799 - duration_loss: 0.0622 - pitch_loss: 0.9856 - step_loss: 0.0684
# Epoch 120/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1772 - duration_loss: 0.0612 - pitch_loss: 0.9610 - step_loss: 0.0679
# Epoch 121/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1740 - duration_loss: 0.0605 - pitch_loss: 0.9471 - step_loss: 0.0661
# Epoch 122/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1713 - duration_loss: 0.0595 - pitch_loss: 0.9101 - step_loss: 0.0663
# Epoch 123/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1690 - duration_loss: 0.0576 - pitch_loss: 0.8920 - step_loss: 0.0668
# Epoch 124/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.1711 - duration_loss: 0.0588 - pitch_loss: 0.9111 - step_loss: 0.0667
# Epoch 125/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1694 - duration_loss: 0.0586 - pitch_loss: 0.8828 - step_loss: 0.0666
# Epoch 126/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1658 - duration_loss: 0.0560 - pitch_loss: 0.8600 - step_loss: 0.0667
# Epoch 127/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1643 - duration_loss: 0.0560 - pitch_loss: 0.8530 - step_loss: 0.0656
# Epoch 128/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1614 - duration_loss: 0.0547 - pitch_loss: 0.8218 - step_loss: 0.0656
# Epoch 129/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1590 - duration_loss: 0.0543 - pitch_loss: 0.7983 - step_loss: 0.0648
# Epoch 130/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1617 - duration_loss: 0.0540 - pitch_loss: 0.7988 - step_loss: 0.0677
# Epoch 131/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1623 - duration_loss: 0.0555 - pitch_loss: 0.8145 - step_loss: 0.0661
# Epoch 132/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1618 - duration_loss: 0.0569 - pitch_loss: 0.7975 - step_loss: 0.0650
# Epoch 133/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1537 - duration_loss: 0.0521 - pitch_loss: 0.7481 - step_loss: 0.0642
# Epoch 134/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1534 - duration_loss: 0.0519 - pitch_loss: 0.7471 - step_loss: 0.0641
# Epoch 135/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1509 - duration_loss: 0.0511 - pitch_loss: 0.7191 - step_loss: 0.0639
# Epoch 136/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1525 - duration_loss: 0.0523 - pitch_loss: 0.7266 - step_loss: 0.0638
# Epoch 137/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1517 - duration_loss: 0.0508 - pitch_loss: 0.7126 - step_loss: 0.0653
# Epoch 138/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1496 - duration_loss: 0.0507 - pitch_loss: 0.7057 - step_loss: 0.0637
# Epoch 139/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1481 - duration_loss: 0.0503 - pitch_loss: 0.6816 - step_loss: 0.0638
# Epoch 140/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1489 - duration_loss: 0.0508 - pitch_loss: 0.6630 - step_loss: 0.0649
# Epoch 141/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1473 - duration_loss: 0.0500 - pitch_loss: 0.6647 - step_loss: 0.0640
# Epoch 142/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1442 - duration_loss: 0.0497 - pitch_loss: 0.6551 - step_loss: 0.0617
# Epoch 143/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1448 - duration_loss: 0.0499 - pitch_loss: 0.6346 - step_loss: 0.0632
# Epoch 144/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1458 - duration_loss: 0.0497 - pitch_loss: 0.6428 - step_loss: 0.0640
# Epoch 145/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1435 - duration_loss: 0.0492 - pitch_loss: 0.6163 - step_loss: 0.0634
# Epoch 146/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1403 - duration_loss: 0.0488 - pitch_loss: 0.5922 - step_loss: 0.0619
# Epoch 147/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1408 - duration_loss: 0.0482 - pitch_loss: 0.5802 - step_loss: 0.0635
# Epoch 148/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1393 - duration_loss: 0.0491 - pitch_loss: 0.5795 - step_loss: 0.0613
# Epoch 149/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1371 - duration_loss: 0.0483 - pitch_loss: 0.5579 - step_loss: 0.0609
# Epoch 150/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1384 - duration_loss: 0.0479 - pitch_loss: 0.5584 - step_loss: 0.0626
# Epoch 151/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.1348 - duration_loss: 0.0469 - pitch_loss: 0.5524 - step_loss: 0.0603
# Epoch 152/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1343 - duration_loss: 0.0466 - pitch_loss: 0.5340 - step_loss: 0.0610
# Epoch 153/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.1349 - duration_loss: 0.0475 - pitch_loss: 0.5284 - step_loss: 0.0610
# Epoch 154/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1338 - duration_loss: 0.0474 - pitch_loss: 0.5388 - step_loss: 0.0595
# Epoch 155/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1336 - duration_loss: 0.0468 - pitch_loss: 0.5304 - step_loss: 0.0603
# Epoch 156/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1403 - duration_loss: 0.0476 - pitch_loss: 0.5783 - step_loss: 0.0637
# Epoch 157/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1361 - duration_loss: 0.0471 - pitch_loss: 0.5257 - step_loss: 0.0627
# Epoch 158/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.1324 - duration_loss: 0.0472 - pitch_loss: 0.5041 - step_loss: 0.0600
# Epoch 159/200
# 45/45 [==============================] - 1s 30ms/step - loss: 0.1349 - duration_loss: 0.0483 - pitch_loss: 0.5068 - step_loss: 0.0613
# Epoch 160/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1328 - duration_loss: 0.0468 - pitch_loss: 0.5041 - step_loss: 0.0608
# Epoch 161/200
# 45/45 [==============================] - 1s 30ms/step - loss: 0.1302 - duration_loss: 0.0459 - pitch_loss: 0.4725 - step_loss: 0.0606
# Epoch 162/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1285 - duration_loss: 0.0458 - pitch_loss: 0.4521 - step_loss: 0.0601
# Epoch 163/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1261 - duration_loss: 0.0454 - pitch_loss: 0.4440 - step_loss: 0.0585
# Epoch 164/200
# 45/45 [==============================] - 1s 29ms/step - loss: 0.1248 - duration_loss: 0.0452 - pitch_loss: 0.4287 - step_loss: 0.0582
# Epoch 165/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.1249 - duration_loss: 0.0460 - pitch_loss: 0.4287 - step_loss: 0.0575
# Epoch 166/200
# 45/45 [==============================] - 1s 30ms/step - loss: 0.1252 - duration_loss: 0.0462 - pitch_loss: 0.4268 - step_loss: 0.0576
# Epoch 167/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1252 - duration_loss: 0.0464 - pitch_loss: 0.4234 - step_loss: 0.0577
# Epoch 168/200
# 45/45 [==============================] - 1s 32ms/step - loss: 0.1235 - duration_loss: 0.0456 - pitch_loss: 0.3969 - step_loss: 0.0580
# Epoch 169/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1226 - duration_loss: 0.0449 - pitch_loss: 0.4088 - step_loss: 0.0572
# Epoch 170/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1292 - duration_loss: 0.0486 - pitch_loss: 0.4295 - step_loss: 0.0590
# Epoch 171/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1239 - duration_loss: 0.0466 - pitch_loss: 0.3902 - step_loss: 0.0579
# Epoch 172/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1240 - duration_loss: 0.0471 - pitch_loss: 0.3814 - step_loss: 0.0579
# Epoch 173/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1205 - duration_loss: 0.0458 - pitch_loss: 0.3622 - step_loss: 0.0566
# Epoch 174/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1206 - duration_loss: 0.0472 - pitch_loss: 0.3579 - step_loss: 0.0555
# Epoch 175/200
# 45/45 [==============================] - 1s 24ms/step - loss: 0.1215 - duration_loss: 0.0483 - pitch_loss: 0.3452 - step_loss: 0.0560
# Epoch 176/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1200 - duration_loss: 0.0461 - pitch_loss: 0.3445 - step_loss: 0.0567
# Epoch 177/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1204 - duration_loss: 0.0461 - pitch_loss: 0.3411 - step_loss: 0.0573
# Epoch 178/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1173 - duration_loss: 0.0452 - pitch_loss: 0.3189 - step_loss: 0.0561
# Epoch 179/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1175 - duration_loss: 0.0442 - pitch_loss: 0.3273 - step_loss: 0.0570
# Epoch 180/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1151 - duration_loss: 0.0433 - pitch_loss: 0.3184 - step_loss: 0.0558
# Epoch 181/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1142 - duration_loss: 0.0433 - pitch_loss: 0.3106 - step_loss: 0.0553
# Epoch 182/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1177 - duration_loss: 0.0440 - pitch_loss: 0.3475 - step_loss: 0.0563
# Epoch 183/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1295 - duration_loss: 0.0475 - pitch_loss: 0.4407 - step_loss: 0.0599
# Epoch 184/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1149 - duration_loss: 0.0433 - pitch_loss: 0.3054 - step_loss: 0.0563
# Epoch 185/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1128 - duration_loss: 0.0433 - pitch_loss: 0.2920 - step_loss: 0.0549
# Epoch 186/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1120 - duration_loss: 0.0425 - pitch_loss: 0.2847 - step_loss: 0.0552
# Epoch 187/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1278 - duration_loss: 0.0458 - pitch_loss: 0.3892 - step_loss: 0.0625
# Epoch 188/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1182 - duration_loss: 0.0443 - pitch_loss: 0.3110 - step_loss: 0.0583
# Epoch 189/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1135 - duration_loss: 0.0437 - pitch_loss: 0.2831 - step_loss: 0.0556
# Epoch 190/200
# 45/45 [==============================] - 1s 28ms/step - loss: 0.1108 - duration_loss: 0.0427 - pitch_loss: 0.2636 - step_loss: 0.0548
# Epoch 191/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1121 - duration_loss: 0.0426 - pitch_loss: 0.2682 - step_loss: 0.0560
# Epoch 192/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1104 - duration_loss: 0.0434 - pitch_loss: 0.2529 - step_loss: 0.0544
# Epoch 193/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1093 - duration_loss: 0.0418 - pitch_loss: 0.2389 - step_loss: 0.0556
# Epoch 194/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1059 - duration_loss: 0.0411 - pitch_loss: 0.2240 - step_loss: 0.0537
# Epoch 195/200
# 45/45 [==============================] - 1s 25ms/step - loss: 0.1079 - duration_loss: 0.0413 - pitch_loss: 0.2354 - step_loss: 0.0548
# Epoch 196/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1085 - duration_loss: 0.0423 - pitch_loss: 0.2306 - step_loss: 0.0547
# Epoch 197/200
# 45/45 [==============================] - 1s 26ms/step - loss: 0.1072 - duration_loss: 0.0416 - pitch_loss: 0.2172 - step_loss: 0.0547
# Epoch 198/200
# 45/45 [==============================] - 1s 31ms/step - loss: 0.1079 - duration_loss: 0.0418 - pitch_loss: 0.2185 - step_loss: 0.0552
# Epoch 199/200
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1063 - duration_loss: 0.0413 - pitch_loss: 0.2098 - step_loss: 0.0545
# Epoch 200/200
# 45/45 [==============================] - 1s 29ms/step - loss: 0.1085 - duration_loss: 0.0425 - pitch_loss: 0.2217 - step_loss: 0.0549

# %%
def predict_next_note(notes: np.ndarray, keras_model: tf.keras.Model, 
                      temperature: float = 1.0) -> int:
    """Generates a note IDs using a trained sequence model."""

    assert temperature > 0

    # Add batch dimension
    inputs = tf.expand_dims(notes, 0)

    predictions = model.predict(inputs)
    pitch_logits = predictions['pitch']
    step = predictions['step']
    duration = predictions['duration']

    pitch_logits /= temperature
    pitch = tf.random.categorical(pitch_logits, num_samples=1)
    pitch = tf.squeeze(pitch, axis=-1)
    duration = tf.squeeze(duration, axis=-1)
    step = tf.squeeze(step, axis=-1)

    # `step` and `duration` values should be non-negative
    step = tf.maximum(0, step)
    duration = tf.maximum(0, duration)

    return int(pitch), float(step), float(duration)

# %%
temperature = 2.0
num_predictions = 120

sample_notes = np.stack([raw_notes[key] for key in key_order], axis=1)

# The initial sequence of notes while the pitch is normalized similar to training sequences
input_notes = (
    sample_notes[:seq_length] / np.array([vocab_size, 1, 1]))

generated_notes = []
prev_start = 0

for _ in range(num_predictions):
    pitch, step, duration = predict_next_note(input_notes, model, temperature)
    start = prev_start + step
    end = start + duration
    input_note = (pitch, step, duration)
    generated_notes.append((*input_note, start, end))
    input_notes = np.delete(input_notes, 0, axis=0)
    input_notes = np.append(input_notes, np.expand_dims(input_note, 0), axis=0)
    prev_start = start

generated_notes = pd.DataFrame(
    generated_notes, columns=(*key_order, 'start', 'end'))

generated_notes.head(10)
# Out:
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
#    pitch      step  duration      start        end
# 0     45  0.780707  5.713892   0.780707   6.494599
# 1     57  2.134147  3.288892   2.914854   6.203746
# 2     53  2.239541  2.413084   5.154395   7.567479
# 3     50  2.074379  1.814904   7.228774   9.043678
# 4     53  2.008085  1.871656   9.236858  11.108514
# 5     50  2.039796  1.672713  11.276655  12.949367
# 6     48  2.077687  1.582066  13.354342  14.936408
# 7     50  2.065502  1.497452  15.419844  16.917295
# 8     48  2.109125  1.557945  17.528969  19.086914
# 9     50  2.114738  1.523353  19.643707  21.167061

# %%
def predict_next_note(notes: np.ndarray, keras_model: tf.keras.Model, 
                      temperature: float = 1.0) -> int:
    """Generates a note IDs using a trained sequence model."""

    assert temperature > 0

    # Add batch dimension
    inputs = tf.expand_dims(notes, 0)

    predictions = model.predict(inputs)
    pitch_logits = predictions['pitch']
    step = predictions['step']
    duration = predictions['duration']

    pitch_logits /= temperature
    pitch = tf.random.categorical(pitch_logits, num_samples=1)
    pitch = tf.squeeze(pitch, axis=-1)
    duration = tf.squeeze(duration, axis=-1)
    step = tf.squeeze(step, axis=-1)

    # `step` and `duration` values should be non-negative
    step = tf.maximum(0, step)
    duration = tf.maximum(0, duration)

    return int(pitch), float(step), float(duration)

# %%
out_file = 'output.midi'
out_pm = notes_to_midi(
    generated_notes, out_file=out_file, instrument_name=instrument_name)
